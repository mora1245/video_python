# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
results = model(source="D:/video/video.mp4", stream=True, show=True, conf=0.4, save=True)

 
for result in results:
    frame = result.plot()
# Out:
# video 1/1 (frame 1/647) D:\video\video.mp4: 384x640 (no detections), 93.0ms
# video 1/1 (frame 2/647) D:\video\video.mp4: 384x640 (no detections), 114.8ms
# video 1/1 (frame 3/647) D:\video\video.mp4: 384x640 (no detections), 132.9ms
# video 1/1 (frame 4/647) D:\video\video.mp4: 384x640 (no detections), 102.4ms
# video 1/1 (frame 5/647) D:\video\video.mp4: 384x640 (no detections), 100.5ms
# video 1/1 (frame 6/647) D:\video\video.mp4: 384x640 (no detections), 80.0ms
# video 1/1 (frame 7/647) D:\video\video.mp4: 384x640 (no detections), 97.8ms
# video 1/1 (frame 8/647) D:\video\video.mp4: 384x640 (no detections), 80.3ms
# video 1/1 (frame 9/647) D:\video\video.mp4: 384x640 (no detections), 79.7ms
# video 1/1 (frame 10/647) D:\video\video.mp4: 384x640 (no detections), 80.3ms
# video 1/1 (frame 11/647) D:\video\video.mp4: 384x640 (no detections), 84.6ms
# video 1/1 (frame 12/647) D:\video\video.mp4: 384x640 (no detections), 75.5ms
# ...
