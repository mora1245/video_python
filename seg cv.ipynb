# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# %%
model = YOLO(r"D:/yolo-cls/yolov8n-seg.pt")
results = model(r"D:/IMAGE/img.jpg")
# Out:
# image 1/1 D:\IMAGE\img.jpg: 448x640 15 persons, 6 cars, 4 traffic lights, 196.9ms
# Speed: 5.0ms preprocess, 196.9ms inference, 45.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
import os 
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()

# %%
import cv2
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')  

cap = cv2.VideoCapture(r"D:\vid\vid.mp4")

out = cv2.VideoWriter(
    r"D:\vid\output_segmented_video.mp4",
    cv2.VideoWriter_fourcc(*"mp4v"),
    cap.get(cv2.CAP_PROP_FPS),
    (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))),
)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
        
        
    result_img = model(frame)[0].plot()
    

    out.write(result_img)
    
    
    cv2.imshow("Processed Frame", result_img)

    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
# Out:
# 0: 384x640 (no detections), 166.0ms
# Speed: 4.0ms preprocess, 166.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 121.0ms
# Speed: 4.0ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.0ms
# Speed: 9.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 272.0ms
# Speed: 3.0ms preprocess, 272.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 264.0ms
# Speed: 7.0ms preprocess, 264.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 172.0ms
# Speed: 10.0ms preprocess, 172.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 108.0ms
# Speed: 5.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
